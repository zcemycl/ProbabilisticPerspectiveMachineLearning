# %%
import numpy as np
import librosa
import os
import matplotlib.pyplot as plt
import scipy
from scipy import signal
import IPython.display as ipd
# %matplotlib inline
import librosa.display
import IPython.display as ipd
import seaborn
import urllib
import sklearn

# %%
wvfileDIR = 'D:/44754/Documents/Data/LJSpeech-1.1/wavs/LJ001-0008.wav'
y,sr = librosa.load(wvfileDIR, 22050) # Sample rate

# %%
# signal processing
sr = 22050 # Sample rate.
n_fft = 2048 # fft points (samples)
frame_shift = 0.0125 # seconds
frame_length = 0.05 # seconds
hop_length = int(sr*frame_shift) # samples.
win_length = int(sr*frame_length) # samples.
n_mels = 80 # Number of Mel banks to generate
power = 1.2 # Exponent for amplifying the predicted magnitude
n_iter = 50 # Number of inversion iterations
preemphasis = .97 # or None
max_db = 100
ref_db = 20

# %%
win_length
# Out:
# 1102

# %% [markdown]
# The **zero-crossing rate** is the rate of sign-changes along a signal, i.e., the rate at which the signal changes from positive to zero to negative or from negative to zero to positive.
# https://en.wikipedia.org/wiki/Zero-crossing_rate

# %%
ipd.Audio(y, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y.shape
# Out:
# (39325,)

# %%
plt.plot(librosa.feature.zero_crossing_rate(y)[0])
print(librosa.feature.zero_crossing_rate(y)[0,0])
# Out:
# 0.0419921875

# %% [markdown]
# The **spectral centroid** is a measure used in digital signal processing to characterise a spectrum. It indicates where the center of mass of the spectrum is located. Perceptually, it has a robust connection with the impression of brightness of a sound.
# https://en.wikipedia.org/wiki/Spectral_centroid

# %%
plt.plot(librosa.feature.spectral_centroid(y)[0])
print(librosa.feature.spectral_centroid(y)[0,0])
# Out:
# 1119.8868869529995

# %% [markdown]
# ### Feature rescaling
# May not be applicable right here. **sklearn.preprocessing.MinMaxScaler**. MinMaxScaler returns an array of scaled values such that each feature dimension is in the range -1 to 1.

# %% [markdown]
# ## Segmentation
# ### Root Mean Square (RMS) Energy

# %%
T = 3.0
amplitude = np.logspace(-3,0,int(T*sr),endpoint=False,base=10)
print(amplitude.min(),amplitude.max())
# Out:
# 0.001 0.9998955798243658

# %%
t = np.linspace(0,T,int(T*sr),endpoint=False)
x = amplitude*np.sin(2*np.pi*440*t)
ipd.Audio(x,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveplot(x,sr=sr)

# %%
frame_len = 1024; hop_len = 512
def rmse(x):
    return np.sqrt(np.mean(x**2))
plt.semilogy([rmse(x[i:i+frame_len]) for i in range(0,len(x),hop_len)])

# %%
frames = librosa.util.frame(x, frame_length=frame_len, hop_length=hop_len)
plt.semilogy([rmse(frame) for frame in frames.T])

# %% [markdown]
# ### Energy and RMSE

# %% [markdown]
# The energy (Wikipedia; FMP, p. 66) of a signal corresponds to the total magntiude of the signal. For audio signals, that roughly corresponds to how loud the signal is. The energy in a signal is defined as
#
# $$\sum_n|x(n)|^2$$
#
# The root-mean-square energy (RMSE) in a signal is defined as
#
# $$\sqrt{\frac{1}{N}\sum_n|x(n)|^2}$$

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(y, sr=sr)
plt.grid(True)

# %%
hop_len2 = 256
frame_len2 = 512
energy=np.array([sum(abs(y[i:i+frame_len2])) for i in range(0,len(y),hop_len2)])

# %%
energy.shape
# Out:
# (154,)

# %% [markdown]
# ### Notes
# Window length in tacotron is equal to Frame length in music retrieval

# %%
rmse = librosa.feature.rms(y,frame_length=win_length,
                           hop_length=hop_length,center=True)

# %%
rmse.shape
# Out:
# (1, 144)

# %%
rmse = rmse[0]

# %%
frames = range(len(rmse))
t = librosa.frames_to_time(frames, sr=sr, hop_length=hop_length)

# %%
print(frames,t.shape)
# Out:
# range(0, 144) (144,)

# %%
plt.figure(figsize=(14, 5))
plt.plot(t,rmse)
librosa.display.waveplot(y, sr=sr)
plt.grid(True)

# %% [markdown]
# ### Strip
# removes leading silence from a signal

# %%
def strip(x,frame_length,hop_length):
    rmse = librosa.feature.rms(x,frame_length=frame_length,
                               hop_length=hop_length,center=True)
    thresh,frame_index = .01,0
    while rmse[0][frame_index]<thresh:
        frame_index += 1
    
    start_sample_index = librosa.frames_to_samples(frame_index,
                                                  hop_length=hop_length)
    return x[start_sample_index:]

# %%
ystrip = strip(y,win_length,hop_length)
print(ystrip.shape)
# Out:
# (39325,)

# %% [markdown]
# ### Zero Crossing Rate

# %%
n0,n1 = 7000,7050
plt.plot(y[n0:n1])
plt.grid(True)
# 3 zero crossing

# %%
zero_crossings = librosa.zero_crossings(y[n0:n1], pad=False)
print(zero_crossings.shape)
print(sum(zero_crossings))
# Out:
# (50,)
# 3

# %%
zcrs = librosa.feature.zero_crossing_rate(y)
print(zcrs.shape)
# Out:
# (1, 77)

# %%
plt.plot(zcrs[0])

# %%
zcrs = librosa.feature.zero_crossing_rate(y+.0001)
plt.plot(zcrs[0])

# %% [markdown]
# ### Fourier Transform

# %%
ffty = scipy.fft(y)
fftymag = np.absolute(ffty)
f = np.linspace(0,sr,len(fftymag))

# %%
print(fftymag.shape)
# Out:
# (39325,)

# %%
plt.plot(f,fftymag)

# %% [markdown]
# ### Short-Time Fourier Transform

# %%
stfty = librosa.stft(y,n_fft=n_fft,hop_length=hop_length)

# %%
stftymag = np.absolute(stfty)
f = np.linspace(0,sr,len(stftymag))
print(stftymag.shape)
# Out:
# (1025, 144)

# %%
S = librosa.amplitude_to_db(abs(stfty))
librosa.display.specshow(S, sr=sr, hop_length=hop_length,
                         x_axis='time', y_axis='linear')

# %% [markdown]
# ### Mel-spectrogram

# %% [markdown]
# The human perception of sound intensity is logarithmic in nature. Therefore, like the STFT-based spectrogram, we are often interested in the log amplitude:

# %%
S = librosa.feature.melspectrogram(y,sr=sr,n_fft=n_fft,
                                   hop_length=hop_length)
logS = librosa.power_to_db(abs(S))
librosa.display.specshow(logS, sr=sr, hop_length=hop_length, x_axis='time', y_axis='mel')

# %% [markdown]
# ### Constant-Q transform
# Unlike the Fourier transform, but similar to the mel scale, the constant-Q transform uses a logarithmically spaced frequency axis.

# %%
fmin = librosa.midi_to_hz(36)
C = librosa.cqt(y,sr=sr,fmin=fmin,n_bins=72)
logC = librosa.amplitude_to_db(abs(C))

# %%
librosa.display.specshow(logC, sr=sr, x_axis='time', y_axis='cqt_note', fmin=fmin, cmap='coolwarm')
plt.colorbar(format='%+2.0f dB')

# %% [markdown]
# ### Chroma
# A chroma vector (Wikipedia) (FMP, p. 123) is a typically a 12-element feature vector indicating how much energy of each pitch class, {C, C#, D, D#, E, ..., B}, is present in the signal.

# %% [markdown]
# #### Chroma STFT

# %%
chromagram = librosa.feature.chroma_stft(y,sr=sr,hop_length=hop_length)
librosa.display.specshow(chromagram, x_axis='time', y_axis='chroma', hop_length=hop_length, cmap='coolwarm')

# %% [markdown]
# #### Chroma CQT

# %%
hop_length
# Out:
# 275

# %%
chromagram = librosa.feature.chroma_cqt(y, sr=sr, hop_length=512)
librosa.display.specshow(chromagram, x_axis='time', y_axis='chroma', hop_length=hop_length, cmap='coolwarm')

# %% [markdown]
# ### Chroma energy normalized statistics (CENS)
# The main idea of CENS features is that taking statistics over large windows smooths local deviations in tempo, articulation, and musical ornaments such as trills and arpeggiated chords. CENS are best used for tasks such as audio matching and similarity.

# %%
chromagram = librosa.feature.chroma_cens(y, sr=sr, hop_length=512)
librosa.display.specshow(chromagram, x_axis='time', y_axis='chroma', hop_length=hop_length, cmap='coolwarm')

# %% [markdown]
# ## Magnitude Scaling

# %%
T = 4.0      # duration in seconds
sr = 22050   # sampling rate in Hertz
t = np.linspace(0, T, int(T*sr), endpoint=False)

# %%
amplitude = np.linspace(0, 1, int(T*sr), endpoint=False) # time-varying amplitude
x = amplitude*np.sin(2*np.pi*440*t)

# %%
ipd.Audio(x,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveplot(x, sr=sr)

# %%
amplitude = np.logspace(-2, 0, int(T*sr), endpoint=False, base=10.0)
x = amplitude*np.sin(2*np.pi*440*t)
ipd.Audio(x,rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveplot(x, sr=sr)

# %% [markdown]
# ### Spectrogram Visualization: Linear Amplitude

# %%
Y = librosa.stft(y)
Y.shape
# Out:
# (1025, 77)

# %%
Ymag = abs(Y)
librosa.display.specshow(Ymag, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()

# %% [markdown]
# ### Spectrogram Visualization: Log Amplitude

# %%
Ydb = librosa.amplitude_to_db(Ymag)
librosa.display.specshow(Ydb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()

# %%
Ymag = np.log10(1+10*abs(Y))
librosa.display.specshow(Ymag, sr=sr, x_axis='time', y_axis='log', cmap="gray_r")
plt.colorbar()

# %% [markdown]
# ### Spectrogram Visualization: Perceptual Weighting

# %%
freqs = librosa.core.fft_frequencies(sr=sr)

# %%
Ymag = librosa.perceptual_weighting(abs(Y)**2, freqs)
librosa.display.specshow(Ymag, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()
# Out:
# C:\Users\44754\Anaconda3\lib\site-packages\librosa\core\time_frequency.py:1208: RuntimeWarning: divide by zero encountered in log10
#   - 0.5 * np.log10(f_sq + const[3]))

# %% [markdown]
# ## Spectral Features
# ### Spectral Centroid
# The spectral centroid indicates at which frequency the energy of a spectrum is centered upon.

# %%
spectral_centroids = librosa.feature.spectral_centroid(y, sr=sr)[0]
spectral_centroids.shape
# Out:
# (77,)

# %%
frames = range(len(spectral_centroids))
t = librosa.frames_to_time(frames)
def normalize(x, axis=0):
    return sklearn.preprocessing.minmax_scale(x, axis=axis)
librosa.display.waveplot(y, sr=sr, alpha=0.4)
plt.plot(t, normalize(spectral_centroids), color='r') 
# normalize for visualization purposes

# %%
spectral_centroids = librosa.feature.spectral_centroid(y+.01, sr=sr)[0]
librosa.display.waveplot(y, sr=sr, alpha=0.4)
plt.plot(t, normalize(spectral_centroids), color='r')

# %% [markdown]
# ### Spectral Bandwidth

# %%
spectral_bandwidth_2 = librosa.feature.spectral_bandwidth(y+0.01, sr=sr)[0]
spectral_bandwidth_3 = librosa.feature.spectral_bandwidth(y+0.01, sr=sr, p=3)[0]
spectral_bandwidth_4 = librosa.feature.spectral_bandwidth(y+0.01, sr=sr, p=4)[0]
librosa.display.waveplot(y, sr=sr, alpha=0.4)
plt.plot(t, normalize(spectral_bandwidth_2), color='r')
plt.plot(t, normalize(spectral_bandwidth_3), color='g')
plt.plot(t, normalize(spectral_bandwidth_4), color='y')
plt.legend(('p = 2', 'p = 3', 'p = 4'))

# %% [markdown]
# ### Spectral Contrast
# Spectral contrast considers the spectral peak, the spectral valley, and their difference in each frequency subband.

# %%
spectral_contrast = librosa.feature.spectral_contrast(y, sr=sr)
spectral_contrast.shape
# Out:
# (7, 77)

# %%
plt.imshow(normalize(spectral_contrast, axis=1), aspect='auto', origin='lower', cmap='coolwarm')

# %% [markdown]
# ### Spectral Rolloff
# Spectral rolloff is the frequency below which a specified percentage of the total spectral energy, e.g. 85%, lies.

# %%
spectral_rolloff = librosa.feature.spectral_rolloff(y+0.01, sr=sr)[0]
librosa.display.waveplot(y, sr=sr, alpha=0.4)
plt.plot(t, normalize(spectral_rolloff), color='r')

# %% [markdown]
# ## Autocorrelation
# The autocorrelation of a signal describes the similarity of a signal against a time-shifted version of itself.

# %%
r = np.correlate(y,y,mode='full')[len(y)-1:]
print(y.shape,r.shape)
# Out:
# (39325,) (39325,)

# %%
plt.figure(figsize=(14, 5))
plt.plot(r[:10000])
plt.xlabel('Lag (samples)')
plt.xlim(0, 10000)
# Out:
# (0, 10000)

# %%
r = librosa.autocorrelate(y, max_size=10000)
print(r.shape)
# Out:
# (10000,)

# %%
plt.figure(figsize=(14, 5))
plt.plot(r)
plt.xlabel('Lag (samples)')
plt.xlim(0, 10000)
# Out:
# (0, 10000)

# %% [markdown]
# ## Pitch Transcription

# %%
bins_per_octave = 36
cqt = librosa.cqt(y, sr=sr, n_bins=300, bins_per_octave=bins_per_octave)
log_cqt = librosa.amplitude_to_db(cqt)
# Out:
# C:\Users\44754\Anaconda3\lib\site-packages\librosa\core\spectrum.py:1700: UserWarning: amplitude_to_db was called on complex input so phase information will be discarded. To suppress this warning, call amplitude_to_db(np.abs(S)) instead.
#   warnings.warn('amplitude_to_db was called on complex input so phase '

# %%
librosa.display.specshow(log_cqt, sr=sr, x_axis='time', y_axis='cqt_note', 
                         bins_per_octave=bins_per_octave)

# %% [markdown]
# ### Step 1: Detect Onsets

# %%
hop_length = 100
onset_env = librosa.onset.onset_strength(y, sr=sr, hop_length=hop_length)
plt.plot(onset_env)
plt.xlim(0, len(onset_env))
# Out:
# (0, 394)

# %%
librosa.display.waveplot(y, sr=sr, alpha=0.4)

# %%
onset_samples = librosa.onset.onset_detect(y,sr=sr, units='time')#, hop_length=hop_length, 
#         backtrack=False,pre_max=20,post_max=20,
#         pre_avg=100,post_avg=100,delta=0.2,wait=0)

# %%
onset_samples
# Out:
# array([0.06965986, 0.13931973, 0.27863946, 0.60371882, 0.7662585 ,
#        0.90557823, 1.04489796, 1.13777778, 1.43963719, 1.67183673])

# %%
onset_boundaries = np.concatenate([[0], onset_samples, [len(y)]])

# %%
onset_times = librosa.samples_to_time(onset_boundaries, sr=sr)

# %%
onset_times
# Out:
# array([0.00000000e+00, 3.15917750e-06, 6.31835501e-06, 1.26367100e-05,
#        2.73795384e-05, 3.47509525e-05, 4.10693075e-05, 4.73876625e-05,
#        5.15998992e-05, 6.52896684e-05, 7.58202601e-05, 1.78344671e+00])

# %%
librosa.display.waveplot(y, sr=sr)
plt.vlines(onset_samples, -1, 1, color='r')

# %% [markdown]
# ### Step 2: Estimate Pitch

# %%
def estimate_pitch(segment, sr, fmin=50.0, fmax=2000.0):
    
    # Compute autocorrelation of input segment.
    r = librosa.autocorrelate(segment)
    
    # Define lower and upper limits for the autocorrelation argmax.
    i_min = sr/fmax
    i_max = sr/fmin
    r[:int(i_min)] = 0
    r[int(i_max):] = 0
    
    # Find the location of the maximum autocorrelation.
    i = r.argmax()
    f0 = float(sr)/i
    return f0

# %% [markdown]
# ### Step 3: Generate Pure Tone

# %%
def generate_sine(f0, sr, n_duration):
    n = np.arange(n_duration)
    return 0.2*np.sin(2*np.pi*f0*n/float(sr))

# %% [markdown]
# ### Step 4: Put it together

# %%
def estimate_pitch_and_generate_sine(x, onset_samples, i, sr):
    n0 = onset_samples[i]
    n1 = onset_samples[i+1]
    f0 = estimate_pitch(x[n0:n1], sr)
    return generate_sine(f0, sr, n1-n0)

# %%
z = np.concatenate([
    estimate_pitch_and_generate_sine(y, onset_boundaries, i, sr=sr)
    for i in range(len(onset_boundaries)-1)
])

# %%
ipd.Audio(z, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
cqt = librosa.cqt(z, gsr=sr)

# %%
librosa.display.specshow(abs(cqt), sr=sr, x_axis='time', y_axis='cqt_note')
